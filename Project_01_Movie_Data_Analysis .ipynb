# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 1 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
#import libraries needed for the data 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
pd.options.display.max_columns = 30 
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Load data and explore basic info

# %%
#load movie data info  
df = pd.read_csv("movies_complete.csv", parse_dates= ["release_date"])

# %%
df.count()
# Out:
# id                       44691
# title                    44691
# tagline                  20284
# release_date             44657
# genres                   42586
# belongs_to_collection     4463
# original_language        44681
# budget_musd               8854
# revenue_musd              7385
# production_companies     33356
# production_countries     38835
# vote_count               44691
# vote_average             42077
# popularity               44691
# runtime                  43179
# overview                 43740
# spoken_languages         41094
# poster_path              44467
# cast                     42502
# cast_size                44691
# crew_size                44691
# director                 43960
# dtype: int64

# %%
# Concise summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
#Explore genre types of any movie
df.genres[1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
#Explore cast for any movie
df.cast[1]
# Out:
# 'Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup|Leonard Zola|Lloyd Berry|Malcolm Stewart|Annabel Kershaw|Darryl Henriques|Robyn Driscoll|Peter Bryant|Sarah Gilson|Florica Vlad|June Lion|Brenda Lockmuller'

# %%
#Pull up summary of data 
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44691.00      8854.00       7385.00    44691.00      42077.00
# mean  107186.24        21.67         68.97      111.65          6.00
# std   111806.36        34.36        146.61      495.32          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26033.50         2.00          2.41        3.00          5.30
# 50%    59110.00         8.20         16.87       10.00          6.10
# 75%   154251.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44691.00 43179.00   44691.00   44691.00
# mean         2.96    97.57      12.48      10.31
# std          6.04    34.65      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# ...

# %%
# Put data into his
df.hist(figsize = (20,12), bins = 100)
plt.show()

# %%
#Explore budget value and count. Do not drop null values 
df.budget_musd.value_counts(dropna = False).head(20)
# Out:
# nan      35837
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 0.50       141
# 35.00      141
# 7.00       137
# 50.00      124
# 1.50       119
# Name: budget_musd, dtype: int64

# %%
#Explore revenue value and count. Do not drop null values
df.revenue_musd.value_counts(dropna = False).head(20)
# Out:
# nan      37306
# 12.00       20
# 11.00       19
# 10.00       19
# 2.00        18
# 6.00        17
# 5.00        14
# 0.50        13
# 8.00        13
# 0.00        12
# 14.00       12
# 7.00        11
# 3.00        10
# 20.00       10
# 1.00        10
# 4.00         9
# 0.00         9
# 1.50         9
# 25.00        8
# 16.00        8
# Name: revenue_musd, dtype: int64

# %%
#Summary with object included
df.describe(include= "object")
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %%
#Explore a title with multiply entries 
df[df.title == "Cinderella"]
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
# ...

# %%
# Use HTML images in display
from IPython.display import HTML

# %%
df_best = df[["poster_path","title","budget_musd","revenue_musd","vote_count","vote_average","popularity"]].copy()

df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# ...

# %%
df_best.iloc[0,0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %%
#Import images display 
from IPython.display import HTML

# %%
#Create best movie from columns / use copy 

df_best = df[["poster_path", "title", "budget_musd","revenue_musd",
              "vote_count", "popularity"]].copy()
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# ...

# %%
# Use subset 
subset = df_best.iloc[:5, :2]
subset
# Out:
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                          title
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %%
#calculate revenue add to table 
df_best = df[["poster_path","title", "budget_musd", "revenue_musd",
             "vote_count", "vote_average", "popularity"]].copy()
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# ...

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
#Calculate revenue solution
df_best["profit_musd"] = df.revenue_musd.sub(df.budget_musd)
df_best["return"] = df.revenue_musd.div(df.budget_musd)

# %%
#profit an return columns added 
df_best.head(5)
# Out:
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                          title  budget_musd  revenue_musd  vote_count  \
# 0                    Toy Story        30.00        373.55     5415.00
# 1                      Jumanji        65.00        262.80     2413.00
# 2             Grumpier Old Men          nan           nan       92.00
# 3            Waiting to Exhale        16.00         81.45       34.00
# 4  Father of the Bride Part II          nan         76.58      173.00
#
#    vote_average  popularity  profit_musd  return
# 0          7.70       21.95       343.55   12.45
# 1          6.90       17.02       197.80    4.04
# 2          6.50       11.71          nan     nan
# ...

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
#Find 5 highest budget movie 
df_best.sort_values(by = "budget_musd", ascending = False).head(5)
# Out:
#                                              poster_path  \
# 16986  <img src='http://image.tmdb.org/t/p/w185//keGf...
# 11743  <img src='http://image.tmdb.org/t/p/w185//oVh3...
# 26268  <img src='http://image.tmdb.org/t/p/w185//4ssD...
# 10985  <img src='http://image.tmdb.org/t/p/w185//6ZYO...
# 18517  <img src='http://image.tmdb.org/t/p/w185//7GSS...
#
#                                              title  budget_musd  revenue_musd  \
# 16986  Pirates of the Caribbean: On Stranger Tides       380.00       1045.71
# 11743     Pirates of the Caribbean: At World's End       300.00        961.00
# 26268                      Avengers: Age of Ultron       280.00       1405.40
# 10985                             Superman Returns       270.00        391.08
# 18517                                  John Carter       260.00        284.14
#
#        vote_count  vote_average  popularity  profit_musd  return
# 16986     5068.00          6.40       27.89       665.71    2.75
# ...

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
# Revenue - budget = highest profit  
df_best["highest profit"] = df.revenue_musd.sub(df.budget_musd)

# %%
df_best.head(5)
# Out:
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                          title  budget_musd  revenue_musd  vote_count  \
# 0                    Toy Story        30.00        373.55     5415.00
# 1                      Jumanji        65.00        262.80     2413.00
# 2             Grumpier Old Men          nan           nan       92.00
# 3            Waiting to Exhale        16.00         81.45       34.00
# 4  Father of the Bride Part II          nan         76.58      173.00
#
#    vote_average  popularity  profit_musd  return  highest profit
# 0          7.70       21.95       343.55   12.45          343.55
# 1          6.90       17.02       197.80    4.04          197.80
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
#Revenue - budget bottom 5 movies
df_best.sort_values(by = "budget_musd", ascending = True).tail(5)
# Out:
#                                              poster_path                title  \
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...               Subdue
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...  Century of Birthing
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...             Betrayal
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...     Satan Triumphant
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...             Queerama
#
#        budget_musd  revenue_musd  vote_count  vote_average  popularity  \
# 44686          nan           nan        1.00          4.00        0.07
# 44687          nan           nan        3.00          9.00        0.18
# 44688          nan           nan        6.00          3.80        0.90
# 44689          nan           nan        0.00           nan        0.00
# 44690          nan           nan        0.00           nan        0.16
#
#        profit_musd  return  highest profit
# ...

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
df_best["ROI"] = df.revenue_musd.div(df.budget_musd)
df_best.head()
# Out:
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                          title  budget_musd  revenue_musd  vote_count  \
# 0                    Toy Story        30.00        373.55     5415.00
# 1                      Jumanji        65.00        262.80     2413.00
# 2             Grumpier Old Men          nan           nan       92.00
# 3            Waiting to Exhale        16.00         81.45       34.00
# 4  Father of the Bride Part II          nan         76.58      173.00
#
#    vote_average  popularity  profit_musd  return  highest profit   ROI
# 0          7.70       21.95       343.55   12.45          343.55 12.45
# 1          6.90       17.02       197.80    4.04          197.80  4.04
# ...

# %%
#Only movies with budget of 5 million +  
df_best.loc[df_best.budget_musd >= 5].sort_values(by = "ROI", ascending = False).head()
# Out:
#                                             poster_path  \
# 1055  <img src='http://image.tmdb.org/t/p/w185//cBfk...
# 5123  <img src='http://image.tmdb.org/t/p/w185//3TB2...
# 255   <img src='http://image.tmdb.org/t/p/w185//6FfC...
# 1327  <img src='http://image.tmdb.org/t/p/w185//s2xc...
# 2333  <img src='http://image.tmdb.org/t/p/w185//kiwO...
#
#                            title  budget_musd  revenue_musd  vote_count  \
# 1055  E.T. the Extra-Terrestrial        10.50        792.97     3359.00
# 5123    My Big Fat Greek Wedding         5.00        368.74      686.00
# 255                    Star Wars        11.00        775.40     6778.00
# 1327                        Jaws         7.00        470.65     2628.00
# 2333            Crocodile Dundee         5.00        328.20      512.00
#
#       vote_average  popularity  profit_musd  return  highest profit   ROI
# 1055          7.30       19.36       782.47   75.52          782.47 75.52
# ...

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
df_best["ROI"] = df.revenue_musd.div(df.budget_musd)
df_best.tail()
# Out:
#                                              poster_path                title  \
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...               Subdue
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...  Century of Birthing
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...             Betrayal
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...     Satan Triumphant
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...             Queerama
#
#        budget_musd  revenue_musd  vote_count  vote_average  popularity  \
# 44686          nan           nan        1.00          4.00        0.07
# 44687          nan           nan        3.00          9.00        0.18
# 44688          nan           nan        6.00          3.80        0.90
# 44689          nan           nan        0.00           nan        0.00
# 44690          nan           nan        0.00           nan        0.16
#
#        profit_musd  return  highest profit  ROI
# ...

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
df_best.sort_values(by = "vote_count", ascending = False).head()
# Out:
#                                              poster_path            title  \
# 15368  <img src='http://image.tmdb.org/t/p/w185//9gk7...        Inception
# 12396  <img src='http://image.tmdb.org/t/p/w185//qJ2t...  The Dark Knight
# 14448  <img src='http://image.tmdb.org/t/p/w185//btnl...           Avatar
# 17669  <img src='http://image.tmdb.org/t/p/w185//RYMX...     The Avengers
# 26272  <img src='http://image.tmdb.org/t/p/w185//fSRb...         Deadpool
#
#        budget_musd  revenue_musd  vote_count  vote_average  popularity  \
# 15368       160.00        825.53    14075.00          8.10       29.11
# 12396       185.00       1004.56    12269.00          8.30      123.17
# 14448       237.00       2787.97    12114.00          7.20      185.07
# 17669       220.00       1519.56    12000.00          7.40       89.89
# 26272        58.00        783.11    11444.00          7.40      187.86
#
#        profit_musd  return  highest profit   ROI
# ...

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
df_best["best_rating"] = df.vote_count.div(df.vote_average)
df_best.head()
# Out:
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                          title  budget_musd  revenue_musd  vote_count  \
# 0                    Toy Story        30.00        373.55     5415.00
# 1                      Jumanji        65.00        262.80     2413.00
# 2             Grumpier Old Men          nan           nan       92.00
# 3            Waiting to Exhale        16.00         81.45       34.00
# 4  Father of the Bride Part II          nan         76.58      173.00
#
#    vote_average  popularity  profit_musd  return  highest profit   ROI  \
# 0          7.70       21.95       343.55   12.45          343.55 12.45
# 1          6.90       17.02       197.80    4.04          197.80  4.04
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
df_best["best_rating"] = df.vote_count.div(df.vote_average)
df_best.tail()
# Out:
#                                              poster_path                title  \
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...               Subdue
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...  Century of Birthing
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...             Betrayal
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...     Satan Triumphant
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...             Queerama
#
#        budget_musd  revenue_musd  vote_count  vote_average  popularity  \
# 44686          nan           nan        1.00          4.00        0.07
# 44687          nan           nan        3.00          9.00        0.18
# 44688          nan           nan        6.00          3.80        0.90
# 44689          nan           nan        0.00           nan        0.00
# 44690          nan           nan        0.00           nan        0.16
#
#        profit_musd  return  highest profit  ROI  best_rating
# ...

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
df_best.sort_values(by = "popularity", ascending = False).head()
# Out:
#                                              poster_path  \
# 30330  <img src='http://image.tmdb.org/t/p/w185//tMaG...
# 32927  <img src='http://image.tmdb.org/t/p/w185//gfJG...
# 41556  <img src='http://image.tmdb.org/t/p/w185//tWqi...
# 42940  <img src='http://image.tmdb.org/t/p/w185//rmnQ...
# 24187  <img src='http://image.tmdb.org/t/p/w185//xozr...
#
#                       title  budget_musd  revenue_musd  vote_count  \
# 30330               Minions        74.00       1156.73     4729.00
# 32927          Wonder Woman       149.00        820.58     5025.00
# 41556  Beauty and the Beast       160.00       1262.89     5530.00
# 42940           Baby Driver        34.00        224.51     2083.00
# 24187            Big Hero 6       165.00        652.11     6289.00
#
#        vote_average  popularity  profit_musd  return  highest profit   ROI  \
# 30330          6.40      547.49      1082.73   15.63         1082.73 15.63
# ...

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (highest rating)__

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
#Filter movies by actor and genres 
df.genres[0]
# Out:
# 'Animation|Comedy|Family'

# %%
# Action & Sceince Fiction genre
mask_genres = df.genres.str.contains("Action") & df.genres.str.contains("Science Fiction")
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
df.cast[0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %%
mask_actor = df.cast.str.contains("Bruce Willis")
mask_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
# Show highest rated movies for the genre 
df.loc[mask_actor & mask_genres, ["title", "vote_average"]].sort_values(by = "vote_average",
                                                                       ascending = False)
# Out:
#                        title  vote_average
# 1448       The Fifth Element          7.30
# 19218                 Looper          6.60
# 1786              Armageddon          6.50
# 14135             Surrogates          5.90
# 20333  G.I. Joe: Retaliation          5.40
# 27619                   Vice          4.10

# %%
bruce = df.loc[mask_actor & mask_genres, ["title","poster_path","vote_average"]].sort_values(by = "vote_average",
                                                                                            ascending = False)

# %%
# Image with movie name and vote average
HTML(bruce.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1448</th>
#       <td>The Fifth Element</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>19218</th>
#       <td>Looper</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>1786</th>
#       <td>Armageddon</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>14135</th>
#       <td>Surrogates</td>
# ...

# %%
#Bruce Willis count for actions / sci fi movies 
bruce.count()
# Out:
# title           6
# poster_path     6
# vote_average    6
# dtype: int64

# %%
# Movies with Uma Thurman and directed by Quentin Tarantino
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
mask_director = df.director == "Quentin Tarantino"

# %%
mask_actor = df.cast.str.contains("Uma Thurma")

# %%
# sort movies by run time 
quentin = df.loc[mask_director & mask_actor,
                ["title","poster_path","runtime"]].sort_values(by = "runtime").set_index("title")

# %%
HTML(quentin.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kill Bill: Vol. 1</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.00</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>154.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Most Successful Pixar Studio Movies between 2010 and 2015

# Explore data set for Pixar Studios
df.production_companies
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures|Teitler Film|Interscope Commu...
# 2                              Warner Bros.|Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4                Sandollar Productions|Touchstone Pictures
#                                ...
# 44686                                                  NaN
# 44687                                          Sine Olivia
# 44688                              American World Pictures
# 44689                                            Yermoliev
# 44690                                                  NaN
# Name: production_companies, Length: 44691, dtype: object

# %%
#How many pixar movies 
df[df.production_companies == "Pixar Animation Studios"].count()
# Out:
# id                       28
# title                    28
# tagline                   8
# release_date             28
# genres                   28
# belongs_to_collection     3
# original_language        28
# budget_musd               4
# revenue_musd              4
# production_companies     28
# production_countries     25
# vote_count               28
# vote_average             28
# popularity               28
# runtime                  28
# overview                 28
# spoken_languages         28
# poster_path              28
# cast                     20
# cast_size                28
# crew_size                28
# director                 28
# dtype: int64

# %%
# Filter Pixar movies from 2010-2015 
mask_production_company = df.production_companies.str.contains("Pixar Animation Studios").fillna(False)
mask_production_company
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: production_companies, Length: 44691, dtype: bool

# %%
 df.release_date
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 44686          NaT
# 44687   2011-11-17
# 44688   2003-08-01
# 44689   1917-10-21
# 44690   2017-06-09
# Name: release_date, Length: 44691, dtype: datetime64[ns]

# %%
mask_time = df.release_date.between("2010-01-01","2015-12-31")

# %%
pixar = df.loc[mask_production_company & mask_time,
               ["title","poster_path","revenue_musd","release_date"]].sort_values(by = "revenue_musd", ascending = False).set_index("title")

# %%
#Display movies with image
HTML(pixar.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story 3</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>Inside Out</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#       <td>2015-06-09</td>
#     </tr>
#     <tr>
#       <th>Monsters University</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>743.56</td>
#       <td>2013-06-20</td>
#     </tr>
# ...

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 44686                               NaN
# 44687                               NaN
# 44688                               NaN
# 44689                               NaN
# 44690                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
#Create Franchise column
df["Franchise"] = df.belongs_to_collection.notna()

# %%
df.Franchise
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: Franchise, Length: 44691, dtype: bool

# %%
df.Franchise.value_counts()
# Out:
# False    40228
# True      4463
# Name: Franchise, dtype: int64

# %%
#Calculate average revenue 
df.groupby("Franchise").revenue_musd.mean()
# Out:
# Franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
#Calculate ROI / add column
df["ROI"] = df.revenue_musd.div(df.budget_musd)

# %%
df.groupby("Franchise").ROI.median()
# Out:
# Franchise
# False   1.62
# True    3.71
# Name: ROI, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby("Franchise").budget_musd.mean()
# Out:
# Franchise
# False   18.05
# True    38.32
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby("Franchise").popularity.mean()
# Out:
# Franchise
# False   2.59
# True    6.25
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby("Franchise").agg({"budget_musd":"mean","revenue_musd": "mean", "vote_count": "mean",
                             "popularity": "mean","ROI": "mean","vote_count": "mean"})
# Out:
#            budget_musd  revenue_musd  vote_count  popularity     ROI
# Franchise
# False            18.05         44.74       78.29        2.59 6966.39
# True             38.32        165.71      412.39        6.25  856.40

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 44686                               NaN
# 44687                               NaN
# 44688                               NaN
# 44689                               NaN
# 44690                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
df.belongs_to_collection.value_counts()
# Out:
# The Bowery Boys                  29
# Totò Collection                  27
# Zatôichi: The Blind Swordsman    26
# James Bond Collection            26
# The Carry On Collection          25
#                                  ..
# Hard Time Collection              1
# Fred Collection                   1
# The Big Bottom Box                1
# All of My Heart Collection        1
# Rico, Oskar 1, 2 & 3              1
# Name: belongs_to_collection, Length: 1691, dtype: int64

# %%
# find best franchises with - total number of movies / total & mean budget / total & mean revenue / mean rating
franchises = df.groupby("belongs_to_collection").agg({"title":"count", "budget_musd": ["sum","mean"], 
                                                     "revenue_musd": ["sum","mean"],
                                                     "vote_average": "mean", "popularity": "mean",
                                                     "ROI":"median",
                                                     "vote_count": "mean"})

# %%
#explore franchise data with selected columns 
franchises
# Out:
#                                      title budget_musd       revenue_musd  \
#                                      count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                2      130.00 65.00       366.78
# 00 Schneider Filmreihe                   1        0.00   nan         0.00
# 08/15 Collection                         1        0.00   nan         0.00
# 100 Girls Collection                     2        0.00   nan         0.00
# 101 Dalmatians (Animated) Collection     2        4.00  4.00       215.88
# ...                                    ...         ...   ...          ...
# Сказки Чуковского                        1        0.00   nan         0.00
# Чебурашка и крокодил Гена                1        0.00   nan         0.00
# Что Творят мужчины! (Коллекция)          2        2.00  2.00         0.00
# 男はつらいよ シリーズ                              3        0.00   nan         0.00
# ...

# %%
# Title and count in descending order max 20 
franchises.nlargest(20, ("title","count"))
# Out:
#                                        title budget_musd       revenue_musd  \
#                                        count         sum  mean          sum
# belongs_to_collection
# The Bowery Boys                           29        0.00   nan         0.00
# Totò Collection                           27        0.00   nan         0.00
# James Bond Collection                     26     1539.65 59.22      7106.97
# Zatôichi: The Blind Swordsman             26        0.00   nan         0.00
# The Carry On Collection                   25        0.00   nan         0.00
# Charlie Chan (Sidney Toler) Collection    21        0.00   nan         0.00
# Pokémon Collection                        20      250.72 50.14       601.87
# Godzilla (Showa) Collection               16        2.81  0.56         0.00
# Charlie Chan (Warner Oland) Collection    15        0.00   nan         0.00
# Dragon Ball Z (Movie) Collection          15        5.00  5.00       112.12
# ...

# %%
# Franchises with highest revenue
franchises.nlargest(20, ("revenue_musd","sum"))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# Star Wars Collection                    8      854.35 106.79      7434.49
# James Bond Collection                  26     1539.65  59.22      7106.97
# The Fast and the Furious Collection     8     1009.00 126.12      5125.10
# Pirates of the Caribbean Collection     5     1250.00 250.00      4521.58
# Transformers Collection                 5      965.00 193.00      4366.10
# Despicable Me Collection                6      299.00  74.75      3691.07
# The Twilight Collection                 5      385.00  77.00      3342.11
# Ice Age Collection                      5      429.00  85.80      3216.71
# Jurassic Park Collection                4      379.00  94.75      3031.48
# ...

# %%
#Franchises with highest budget 
franchises.nlargest(20, ("budget_musd","sum"))
# Out:
#                                         title budget_musd        revenue_musd  \
#                                         count         sum   mean          sum
# belongs_to_collection
# James Bond Collection                      26     1539.65  59.22      7106.97
# Harry Potter Collection                     8     1280.00 160.00      7707.37
# Pirates of the Caribbean Collection         5     1250.00 250.00      4521.58
# The Fast and the Furious Collection         8     1009.00 126.12      5125.10
# X-Men Collection                            6      983.00 163.83      2808.83
# Transformers Collection                     5      965.00 193.00      4366.10
# Star Wars Collection                        8      854.35 106.79      7434.49
# The Hobbit Collection                       3      750.00 250.00      2935.52
# The Terminator Collection                   5      661.40 132.28      1845.33
# Mission: Impossible Collection              5      650.00 130.00      2778.98
# ...

# %%
#Franchises with highest voter count over 1000+
franchises[franchises[("vote_count", "mean")]>=1000].nlargest(20, ("vote_average", "mean"))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# The Godfather Collection                3       73.00  24.33       429.38
# Blade Runner Collection                 1       28.00  28.00        33.14
# The Man With No Name Collection         3        2.00   0.67        35.50
# The Dark Knight Collection              3      585.00 195.00      2463.72
# Guardians of the Galaxy Collection      2      370.00 185.00      1636.74
# Kill Bill Collection                    2       60.00  30.00       333.11
# Kingsman Collection                     1       81.00  81.00       414.35
# How to Train Your Dragon Collection     2      310.00 155.00      1104.00
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# ...

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
#Explore directors data 
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
df.director.value_counts()
# Out:
# John Ford            66
# Michael Curtiz       65
# Werner Herzog        54
# Alfred Hitchcock     53
# Georges Méliès       49
#                      ..
# Ariane Mnouchkine     1
# Josh Bear             1
# Joachim Hedén         1
# Mark L. Bussler       1
# George Dugdale        1
# Name: director, Length: 17349, dtype: int64

# %%
#Use a bar graph to show the director data 
plt.figure(figsize = (12, 8))
df.director.value_counts().head(20).plot(kind= 'bar', fontsize = 20)
plt.title("Most Active Directors", fontsize = 20)
plt.ylabel("Number of Movies", fontsize = 15)
plt.show()

# %%
#which directors made the most revenue?
df.groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Steven Spielberg    9256.62
# Peter Jackson       6528.24
# Michael Bay         6437.47
# James Cameron       5900.61
# David Yates         5334.56
# Christopher Nolan   4747.41
# Robert Zemeckis     4138.23
# Tim Burton          4032.92
# Ridley Scott        3917.53
# Chris Columbus      3866.84
# Roland Emmerich     3798.40
# Ron Howard          3714.15
# J.J. Abrams         3579.22
# Gore Verbinski      3575.34
# George Lucas        3341.55
# Sam Raimi           3193.79
# Francis Lawrence    3183.34
# Clint Eastwood      3100.68
# Bill Condon         3017.30
# Joss Whedon         2963.83
# Name: revenue_musd, dtype: float64

# %%
#Put revenue into bar graph 
plt.figure(figsize = (12, 8))
df.groupby("director").revenue_musd.sum().nlargest(20).plot(kind = 'bar', fontsize = 15)
plt.title("Total Revenue", fontsize = 20)
plt.ylabel("Revenue in MUSD", fontsize = 20)
plt.show()

# %%
# Find mean rating for directors: title / vote average / vote count 
directors = df.groupby("director").agg({"title": "count", "vote_average": "mean", "vote_count": "sum"})

# %%
directors
# Out:
#                      title  vote_average  vote_count
# director
#  Dale Trevillion\t       2          4.00        4.00
#  Davide Manuli           1          6.90       10.00
#  E.W. Swackhamer         1          5.90        5.00
#  Vitaliy Vorobyov        1          5.50        3.00
#  Yeon Sang-Ho            4          6.60     1039.00
# ...                    ...           ...         ...
# Ярополк Лапшин           1         10.00        1.00
# پیمان معادی              1          6.00        2.00
# 塩谷 直義                    1          7.20       40.00
# 杰森·莫玛                    1          5.80       28.00
# 진모영                      1          6.00        6.00
#
# [17349 rows x 3 columns]

# %%
#Explore 10000+ votes with directors who have more than 10 movies completed
directors[(directors.vote_count >= 10000) & (directors.title >= 10)].nlargest(20, "vote_average")
# Out:
#                    title  vote_average  vote_count
# director
# Hayao Miyazaki        14          7.70    14700.00
# Christopher Nolan     11          7.62    67344.00
# Quentin Tarantino     10          7.49    45910.00
# Wes Anderson          10          7.37    11743.00
# David Fincher         10          7.35    37588.00
# Martin Scorsese       39          7.22    35541.00
# Peter Jackson         13          7.14    47571.00
# Joel Coen             17          7.02    18139.00
# James Cameron         11          6.93    33736.00
# Stanley Kubrick       16          6.91    18214.00
# James Mangold         10          6.90    16607.00
# Steven Spielberg      33          6.89    62266.00
# Danny Boyle           14          6.87    16504.00
# Guy Ritchie           10          6.80    19626.00
# Robert Zemeckis       19          6.79    37666.00
# Terry Gilliam         14          6.76    10049.00
# Tim Burton            21          6.73    36922.00
# ...

# %%
#Directors and genre with best average rating 
#Explore genres
df.genres
# Out:
# 0         Animation|Comedy|Family
# 1        Adventure|Fantasy|Family
# 2                  Romance|Comedy
# 3            Comedy|Drama|Romance
# 4                          Comedy
#                    ...
# 44686                Drama|Family
# 44687                       Drama
# 44688       Action|Drama|Thriller
# 44689                         NaN
# 44690                         NaN
# Name: genres, Length: 44691, dtype: object

# %%
df.genres.value_counts().nlargest(20)
# Out:
# Drama                   4935
# Comedy                  3581
# Documentary             2670
# Drama|Romance           1291
# Comedy|Drama            1125
# Horror                   962
# Comedy|Romance           921
# Comedy|Drama|Romance     591
# Drama|Comedy             528
# Horror|Thriller          527
# Drama|Thriller           492
# Thriller                 458
# Crime|Drama              429
# Romance|Drama            335
# Western                  316
# Action|Thriller          300
# Action                   276
# Drama|Foreign            274
# Drama|History            266
# Animation                241
# Name: genres, dtype: int64

# %%
#Find 3 genres with highest revenue with director 
df.genres = df.genres.astype(str)

# %%
#Horror genre
df.loc[df.genres.str.contains("Horror")].groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Paul W.S. Anderson    982.29
# James Wan             861.31
# Wes Craven            834.93
# Francis Lawrence      816.23
# Ridley Scott          689.00
# Marc Forster          531.87
# Steven Spielberg      500.10
# William Friedkin      466.40
# Darren Lynn Bousman   456.34
# M. Night Shyamalan    375.37
# Henry Joost           349.07
# David R. Ellis        348.74
# Adrian Lyne           346.11
# James DeMonaco        316.70
# Stephen Sommers       311.46
# Gore Verbinski        275.91
# Guillermo del Toro    261.63
# John R. Leonetti      255.27
# Fede Alvarez          254.64
# Jordan Peele          252.43
# Name: revenue_musd, dtype: float64

# %%
# Drama genre
df.loc[df.genres.str.contains("Drama")].groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Christopher Nolan    3768.44
# Steven Spielberg     3022.09
# Ridley Scott         2631.99
# Robert Zemeckis      2101.87
# Clint Eastwood       2074.89
# James Cameron        1845.03
# Martin Scorsese      1808.36
# David Fincher        1652.26
# M. Night Shyamalan   1628.16
# Ron Howard           1624.15
# Wolfgang Petersen    1489.16
# Ang Lee              1434.93
# Oliver Stone         1366.18
# Edward Zwick         1204.07
# Mel Gibson           1142.14
# Barry Levinson       1125.59
# Matt Reeves          1104.70
# Bill Condon          1028.30
# Sylvester Stallone    998.46
# Paul Greengrass       998.27
# Name: revenue_musd, dtype: float64

# %%
#Comedy genre
df.loc[df.genres.str.contains("Comedy")].groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Carlos Saldanha    2532.45
# Barry Sonnenfeld   2397.85
# John Lasseter      2256.02
# Robert Zemeckis    2212.70
# Kyle Balda         2176.79
# Pete Docter        2155.53
# Raja Gosnell       1927.22
# Shawn Levy         1919.32
# Todd Phillips      1768.63
# Chris Columbus     1755.51
# Jay Roach          1722.55
# Garry Marshall     1633.67
# Dennis Dugan       1617.05
# Ivan Reitman       1585.53
# Andrew Adamson     1404.25
# Tom Shadyac        1398.56
# Mike Mitchell      1261.99
# Nancy Meyers       1248.68
# Bobby Farrelly     1218.71
# Phil Lord          1102.18
# Name: revenue_musd, dtype: float64
